# %%
import dotenv
import os
from sqlalchemy import create_engine
import pandas as pd

dotenv.load_dotenv(override = True)

username=os.getenv("username")
password=os.getenv("password")
host=os.getenv("host")
dbname=os.getenv("dbname")

conn_string = f"mysql+pymysql://{username}:{password}@{host}/{dbname}"
db_engine = create_engine(conn_string)

query = """SELECT *
        FROM dimproduct
        """
df = pd.read_sql(query, db_engine)

db_engine.dispose()

df.shape
df
# Out:
#      ProductKey ProductAlternateKey  ProductSubcategoryKey  \
# 0             1             AR-5381                    NaN
# 1             2             BA-8327                    NaN
# 2             3             BE-2349                    NaN
# 3             4             BE-2908                    NaN
# 4             5             BL-2036                    NaN
# ..          ...                 ...                    ...
# 601         602             BB-8107                    5.0
# 602         603             BB-9108                    5.0
# 603         604          BK-R19B-44                    2.0
# 604         605          BK-R19B-48                    2.0
# 605         606          BK-R19B-52                    2.0
#
#     WeightUnitMeasureCode SizeUnitMeasureCode     EnglishProductName  \
# 0                    None                None        Adjustable Race
# 1                    None                None           Bearing Ball
# ...

# %%
numero_totale_di_dati = len(df)
print (numero_totale_di_dati)
# Out:
# 606

# %%
metadati = df.dtypes
metadati
# Out:
# ProductKey                        int64
# ProductAlternateKey              object
# ProductSubcategoryKey           float64
# WeightUnitMeasureCode            object
# SizeUnitMeasureCode              object
# EnglishProductName               object
# SpanishProductName               object
# FrenchProductName                object
# StandardCost                    float64
# FinishedGoodsFlag                 int64
# Color                            object
# SafetyStockLevel                  int64
# ReorderPoint                      int64
# ListPrice                       float64
# Size                             object
# SizeRange                        object
# Weight                          float64
# DaysToManufacture                 int64
# ProductLine                      object
# DealerPrice                     float64
# Class                            object
# Style                            object
# ModelName                        object
# ...

# %%
df.head(1)
# Out:
#    ProductKey ProductAlternateKey  ProductSubcategoryKey  \
# 0           1             AR-5381                    NaN
#
#   WeightUnitMeasureCode SizeUnitMeasureCode EnglishProductName  \
# 0                  None                None    Adjustable Race
#
#   SpanishProductName FrenchProductName  StandardCost  FinishedGoodsFlag  ...  \
# 0                                                NaN                  0  ...
#
#   ChineseDescription  ArabicDescription  HebrewDescription  ThaiDescription  \
# 0               None               None               None             None
#
#   GermanDescription JapaneseDescription  TurkishDescription  StartDate  \
# 0              None                None                None 2003-07-01
#
#   EndDate   Status
# 0     NaT  Current
#
# [1 rows x 36 columns]

# %%
df.iloc[0]
# Out:
# ProductKey                                                               1
# ProductAlternateKey                                                AR-5381
# ProductSubcategoryKey                                                  NaN
# WeightUnitMeasureCode                                                 None
# SizeUnitMeasureCode                                                   None
# EnglishProductName                                         Adjustable Race
# SpanishProductName
# FrenchProductName
# StandardCost                                                           NaN
# FinishedGoodsFlag                                                        0
# Color                                                                   NA
# SafetyStockLevel                                                      1000
# ReorderPoint                                                           750
# ListPrice                                                              NaN
# ...

# %%
df.iloc[-1]
# Out:
# ProductKey                                                             606
# ProductAlternateKey                                             BK-R19B-52
# ProductSubcategoryKey                                                  2.0
# WeightUnitMeasureCode                                                   LB
# SizeUnitMeasureCode                                                     CM
# EnglishProductName                                      Road-750 Black, 52
# SpanishProductName                               Carretera: 750, negra, 52
# FrenchProductName                               Vélo de route 750 noir, 52
# StandardCost                                                        343.65
# FinishedGoodsFlag                                                        1
# Color                                                                Black
# SafetyStockLevel                                                       100
# ...

# %%
df.tail(1)
# Out:
#      ProductKey ProductAlternateKey  ProductSubcategoryKey  \
# 605         606          BK-R19B-52                    2.0
#
#     WeightUnitMeasureCode SizeUnitMeasureCode  EnglishProductName  \
# 605                    LB                  CM  Road-750 Black, 52
#
#             SpanishProductName           FrenchProductName  StandardCost  \
# 605  Carretera: 750, negra, 52  Vélo de route 750 noir, 52        343.65
#
#      FinishedGoodsFlag  ...                 ChineseDescription  \
# 605                  1  ...  入门级成人自行车；确保越野旅行或公路骑乘的舒适。快拆式车毂和轮缘。
#
#                                      ArabicDescription  \
# 605  إنها دراجة مناسبة للمبتدئين من البالغين؛ فهي ت...
#
#                                      HebrewDescription  \
# 605  אופני מבוגרים למתחילים; מציעים רכיבה נוחה "מחו...
#
#                                        ThaiDescription  \
# 605  จักรยานระดับเริ่มต้นสำหรับผู้ใหญ่ ให้ความสบายใ...
#
#                                      GermanDescription  \
# ...

# %%
elementi_casuali = df.sample(5)
elementi_casuali
# Out:
#      ProductKey ProductAlternateKey  ProductSubcategoryKey  \
# 455         456           TG-W091-S                   24.0
# 343         344          BK-M82S-38                    1.0
# 489         490           SJ-0194-L                   21.0
# 187         188             SA-M237                    NaN
# 485         486             ST-1401                   27.0
#
#     WeightUnitMeasureCode SizeUnitMeasureCode              EnglishProductName  \
# 455                  None                None               Women's Tights, S
# 343                    LB                  CM         Mountain-100 Silver, 38
# 489                  None                None  Short-Sleeve Classic Jersey, L
# 187                  None                None       ML Mountain Seat Assembly
# 485                  None                None          All-Purpose Bike Stand
#
#                     SpanishProductName  \
# 455               Mallas para mujer, P
# 343         Montaña: 100, plateada, 38
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 606 entries, 0 to 605
# Data columns (total 36 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ProductKey             606 non-null    int64
#  1   ProductAlternateKey    606 non-null    object
#  2   ProductSubcategoryKey  397 non-null    float64
#  3   WeightUnitMeasureCode  282 non-null    object
#  4   SizeUnitMeasureCode    253 non-null    object
#  5   EnglishProductName     606 non-null    object
#  6   SpanishProductName     606 non-null    object
#  7   FrenchProductName      606 non-null    object
#  8   StandardCost           397 non-null    float64
#  9   FinishedGoodsFlag      606 non-null    int64
#  10  Color                  606 non-null    object
#  11  SafetyStockLevel       606 non-null    int64
#  12  ReorderPoint           606 non-null    int64
#  13  ListPrice              395 non-null    float64
# ...

# %%
colori_disponibili = df["Color"].unique()
colori_disponibili
# Out:
# array(['NA', 'Black', 'Silver', 'Red', 'White', 'Blue', 'Multi', 'Yellow',
#        'Grey', 'Silver/Black'], dtype=object)

# %%
media_peso_prodotti = df["Weight"].mean()
media_peso_prodotti
# Out:
# 56.1932269503546

# %%
peso_minimo= df["Weight"].min()
peso_minimo
# Out:
# 2.12

# %%
peso_max= df["Weight"].max()
peso_max
# Out:
# 1050.0

# %%
prodotti_magg_100kg = df[df["Weight"]>100].shape
prodotti_magg_100kg
# Out:
# (28, 36)

# %%
media_costo_prodotti = df["DealerPrice"].mean()
round(media_costo_prodotti,1)
# Out:
# 448.6

# %%
df_ordinato = df.sort_values(by='DealerPrice' , ascending=False)
quarto_prodotti_costosi = df_ordinato.head(int(len(df_ordinato) / 4))
prezzo_minimo = quarto_prodotti_costosi['DealerPrice'].min()
prezzo_massimo = quarto_prodotti_costosi['DealerPrice'].max()
print (prezzo_massimo,prezzo_minimo)
# Out:
# 2146.962 445.41

# %%
prodotti_blu = df[df['Color'] == 'Blue']

prezzo_medio_blu = prodotti_blu['DealerPrice'].mean()

prezzo_medio_blu
# Out:
# 516.0631785714286

# %%
percentile75 = df["DealerPrice"].quantile(0.75) 

maggiore_percentile75 = df[df["DealerPrice"] >= percentile75]

min = maggiore_percentile75["DealerPrice"].min()
max = maggiore_percentile75["DealerPrice"].max()

percentile75, min, max
# Out:
# (722.5949, 722.5949, 2146.962)

# %%
prodotti_neri_rossi = df[(df['Color'] == 'Red') | (df['Color'] == 'Black')]
prezzo_medio_neri_rossi = prodotti_neri_rossi['DealerPrice'].mean()
prezzo_medio_neri_rossi

#secondo metodo
prodotti_medio_neri_rossi = df[df['Color'].isin(['Red', 'Black'])]
prezzo_medio_neri_rossi = prodotti_medio_neri_rossi['DealerPrice'].mean()
prezzo_medio_neri_rossi
# Out:
# 550.2481873684211
